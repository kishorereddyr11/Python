# %% [markdown]
# **Write `Person` Class as given below and then display it's namespace.**
#
# ```
# Class Name - Person
#
# Attributes:
# name - public
# state - public
# city - private
# age - private
#
# Methods:
# address - public
# It give address of the person as "<name>, <city>, <state>"
# ```

# %%
#Write your code here
class Person:

    def __init__(self,name,state,city,age):
        self.name = name
        self.state = state
        self.__city = city
        self.__age = age

    def address(self):
        print(f'{self.name}, {self.__city}, {self.state}')

# %%
person = Person('Kishore','Telangana','Nalgonda',22)
person.address()
# Out:
# Kishore, Nalgonda, Telangana

# %% [markdown]
# **Write a program to show namespace of object/instance of above(Person) class.**

# %%
print("Namespaces of the above object are : ")
print(person.__dict__)
# Out:
# Namespaces of the above object are :
# {'name': 'Kishore', 'state': 'Telangana', '_Person__city': 'Nalgonda', '_Person__age': 22}
